# %%
#plotting points with scatter()
import matplotlib.pyplot as plt

plt.scatter(2,4)
plt.show()

# %%
#plotting series of Points

x_values = [1,2,3,4,5]
y_values = [1,4,9,16,25]

plt.scatter(x_values , y_values , s = 100)
plt.show()

# %% [markdown]
# Calculating Data Automatically

# %%
x_values = list(range(1 , 1001))
y_values = [x**2 for x in x_values]

plt.scatter(x_values , y_values , s =40)

# %%
#Changing the color
plt.scatter(x_values , y_values , c = 'red' , s = 40)
plt.show()

# %%
plt.scatter(x_values , y_values , c = ( 0 , 0, 0.1) , s = 40)
plt.show()

#values closer to 0 will produce dark colors
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
#Using ColorMap

plt.scatter(x_values , y_values , c = y_values , cmap = plt.cm.Blues , s = 40)
plt.show()

# %%
plt.savefig('abc.png' , bbox_inches = 'tight')
