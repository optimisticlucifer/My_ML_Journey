# %%
import pandas as pd

# %%
import numpy as np

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(randn(5,7),index='A B C D E'.split(),columns='F G H I J K L'.split(),dtype=float)

# %%
df
# Out:
#           F         G         H         I         J         K         L
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310

# %%
#search by column name
df['I']
# Out:
# A    0.184434
# B   -0.031915
# C   -0.178956
# D    1.222940
# E    0.752087
# Name: I, dtype: float64

# %%
#pass  a list of column names
df[["F","I"]]
# Out:
#           F         I
# A  0.331217  0.184434
# B -1.343849 -0.031915
# C -1.306944 -0.178956
# D  0.426007  1.222940
# E -0.573818  0.752087

# %%
df.iloc[:,0:5]
# Out:
#           F         G         H         I         J
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302
# C -1.306944  1.366364  0.693438 -0.178956  1.748724
# D  0.426007 -0.585536  0.284760  1.222940  0.086646
# E -0.573818 -0.442612  0.158848  0.752087  0.710269

# %%
type(df['I'])
# Out:
# pandas.core.series.Series

# %%
df["added"]=df["F"]+df["J"]
df
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310
#
#       added
# A -0.128199
# B -1.471151
# C  0.441779
# D  0.512653
# E  0.136451

# %%
df["Means"]=df.iloc[2:2,4:5]

# %%
df
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310
#
#       added  Means
# A -0.128199    NaN
# B -1.471151    NaN
# C  0.441779    NaN
# D  0.512653    NaN
# E  0.136451    NaN

# %%
df.drop("Means",axis=1)
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310
#
#       added
# A -0.128199
# B -1.471151
# C  0.441779
# D  0.512653
# E  0.136451

# %%
df
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310
#
#       added  Means
# A -0.128199    NaN
# B -1.471151    NaN
# C  0.441779    NaN
# D  0.512653    NaN
# E  0.136451    NaN

# %%
df.drop("Means",axis=1,inplace=True)

# %%
df
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310
#
#       added
# A -0.128199
# B -1.471151
# C  0.441779
# D  0.512653
# E  0.136451

# %%
df.drop("E",axis=0)
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
#
#       added
# A -0.128199
# B -1.471151
# C  0.441779
# D  0.512653

# %%
df.loc["B"]
# Out:
# F       -1.343849
# G       -0.327344
# H       -0.676280
# I       -0.031915
# J       -0.127302
# K        1.936515
# L        0.961225
# added   -1.471151
# Name: B, dtype: float64

# %%
df
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310
#
#       added
# A -0.128199
# B -1.471151
# C  0.441779
# D  0.512653
# E  0.136451

# %%
print(df.iloc[2])
df.iloc[2,2]
# Out:
# F       -1.306944
# G        1.366364
# H        0.693438
# I       -0.178956
# J        1.748724
# K       -0.665983
# L       -0.225441
# added    0.441779
# Name: C, dtype: float64
# 0.6934378736832234

# %%
df
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310
#
#       added
# A -0.128199
# B -1.471151
# C  0.441779
# D  0.512653
# E  0.136451

# %%
df.loc["A","G"]
# Out:
# -0.10408500773511713

# %%
df
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310
#
#       added
# A -0.128199
# B -1.471151
# C  0.441779
# D  0.512653
# E  0.136451

# %%
df>0
# Out:
#        F      G      H      I      J      K      L  added
# A   True  False   True   True  False  False   True  False
# B  False  False  False  False  False   True   True  False
# C  False   True   True  False   True  False  False   True
# D   True  False   True   True   True   True  False   True
# E  False  False   True   True   True  False  False   True

# %%
df[df>0]
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217       NaN  2.269891  0.184434       NaN       NaN  0.653792
# B       NaN       NaN       NaN       NaN       NaN  1.936515  0.961225
# C       NaN  1.366364  0.693438       NaN  1.748724       NaN       NaN
# D  0.426007       NaN  0.284760  1.222940  0.086646  0.032614       NaN
# E       NaN       NaN  0.158848  0.752087  0.710269       NaN       NaN
#
#       added
# A       NaN
# B       NaN
# C  0.441779
# D  0.512653
# E  0.136451

# %%
df
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310
#
#       added
# A -0.128199
# B -1.471151
# C  0.441779
# D  0.512653
# E  0.136451

# %%
df[df["G"]>0]
# Out:
#           F         G         H         I         J         K         L  \
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
#
#       added
# C  0.441779

# %%
df[df["G"]>0]["G"]
# Out:
# C    1.366364
# Name: G, dtype: float64

# %%
df
# Out:
#           F         G         H         I         J         K         L  \
# A  0.331217 -0.104085  2.269891  0.184434 -0.459416 -1.289253  0.653792
# B -1.343849 -0.327344 -0.676280 -0.031915 -0.127302  1.936515  0.961225
# C -1.306944  1.366364  0.693438 -0.178956  1.748724 -0.665983 -0.225441
# D  0.426007 -0.585536  0.284760  1.222940  0.086646  0.032614 -0.098786
# E -0.573818 -0.442612  0.158848  0.752087  0.710269 -0.576268 -1.759310
#
#       added
# A -0.128199
# B -1.471151
# C  0.441779
# D  0.512653
# E  0.136451

# %%
df[df["H"]>0][['K','L']]
# Out:
#           K         L
# A -1.289253  0.653792
# C -0.665983 -0.225441
# D  0.032614 -0.098786
# E -0.576268 -1.759310

# %%
df[(df["H"]>0) & (df["I"]>0)][['K','L']]
# Out:
#           K         L
# A -1.289253  0.653792
# D  0.032614 -0.098786
# E -0.576268 -1.759310
